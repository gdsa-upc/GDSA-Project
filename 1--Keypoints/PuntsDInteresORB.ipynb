# %% [markdown]
# # Localitzador de zones d'interés utilitzant ORB

# %% [markdown]
# Primer de tot importem les llibreries neceissàries:

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# Importem la imatge i utilitzant funcions de la llibreria cv2 detectem els punts d'interés amb la funció detect() i els computem amb compute() i dibuixem els punts amb drawKeypoints(). Per mostrar els resulitats utilitzem imshow de la llibreria matplotlib.pyplot:

# %%
img = cv2.imread('Mercat.JPG',0)
#linea que soluciona un bug de opencv
cv2.ocl.setUseOpenCL(False)
# Initiate STAR detector
orb = cv2.ORB_create(200000)

# find the keypoints with ORB
kp = orb.detect(img,None)

# compute the descriptors with ORB
kp, des = orb.compute(img, kp)

# draw only keypoints location,not size and orientation
img2 = cv2.drawKeypoints(img,kp,None,color=(255,0,0), flags=0)
plt.imshow(img2),plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x7fcfbb8d6f98>, None)

# %% [markdown]
# Observem de color vermell els punts d'interés que s'han trobat a la imatge que corresponen sobretot a contorns o zones amb variacions ràpides de color(com les lletres del cartell).
